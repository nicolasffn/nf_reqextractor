# %%
conda create -n newenvt anaconda python=3.5
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/nicolas/opt/anaconda3/envs/newenvt
#
#   added / updated specs:
#     - anaconda
#     - python=3.5
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alabaster-0.7.10           |   py35hb692fe1_0          15 KB
#     anaconda-5.1.0             |           py35_2          11 KB
#     anaconda-client-1.6.9      |           py35_0         142 KB
#     anaconda-project-0.8.2     |   py35ha24014a_0         462 KB
#     appnope-0.1.0              |   py35hd172556_0           8 KB
#     appscript-1.0.1            |   py35hdfff33c_1         127 KB
#     asn1crypto-0.24.0          |           py35_0         161 KB
#     astroid-1.6.1              |           py35_0         394 KB
#     astropy-2.0.3              |   py35h1de35cc_0         5.3 MB
#     attrs-17.4.0               |           py35_0          42 KB
#     babel-2.5.3                |           py35_0         4.2 MB
#     backports-1.0              |   py35h2556c16_1           4 KB
#     backports.shutil_get_terminal_size-1.0.0|   py35h40fcb1f_2           8 KB
#     beautifulsoup4-4.6.0       |   py35hb75f182_1         139 KB
#     bitarray-0.8.1             |   py35h1de35cc_1          60 KB
#     bkcharts-0.2               |   py35h18a45e2_0         135 KB
#     blaze-0.11.3               |   py35h385aa17_0         616 KB
#     bleach-2.1.2               |           py35_0          32 KB
#     bokeh-0.12.13              |   py35h2f9c1c0_0         3.3 MB
#     boto-2.48.0                |   py35h10f7326_1         1.2 MB
#     bottleneck-1.2.1           |   py35h969083f_0         106 KB
#     bzip2-1.0.6                |       hd86a083_4         111 KB
#     ca-certificates-2017.08.26 |       ha1e5d58_0         290 KB
#     certifi-2018.1.18          |           py35_0         141 KB
#     cffi-1.11.4                |   py35h342bebf_0         203 KB
#     chardet-3.0.4              |   py35h16a84c2_1         178 KB
#     click-6.7                  |   py35hcc65ea6_0         109 KB
#     cloudpickle-0.5.2          |           py35_1          26 KB
#     clyent-1.2.2               |   py35h63ae3d7_0          19 KB
#     colorama-0.3.9             |   py35h1d66b2b_0          24 KB
#     contextlib2-0.5.5          |   py35hc2c67b4_0          16 KB
#     cryptography-2.1.4         |   py35hbbb57dc_0         493 KB
#     curl-7.58.0                |       ha441bb4_0         118 KB
#     cycler-0.10.0              |   py35hb89929e_0          13 KB
#     cython-0.27.3              |   py35h36d65b6_0         2.4 MB
#     cytoolz-0.9.0              |   py35h1de35cc_0         294 KB
#     dask-0.16.1                |           py35_0           3 KB
#     dask-core-0.16.1           |           py35_0         917 KB
#     datashape-0.5.4            |   py35hd065018_0         103 KB
#     dbus-1.12.2                |       h5243cc1_1         437 KB
#     decorator-4.2.1            |           py35_0          17 KB
#     distributed-1.20.2         |           py35_0         680 KB
#     docutils-0.14              |   py35hb13dbd9_0         657 KB
#     entrypoints-0.2.3          |   py35h837ec6f_2           9 KB
#     et_xmlfile-1.0.1           |   py35h40eb147_0          21 KB
#     expat-2.2.5                |       hb8e80ba_0         110 KB
#     fastcache-1.0.2            |   py35h1de35cc_2          27 KB
#     filelock-2.0.13            |   py35haecd4ea_0          12 KB
#     flask-0.12.2               |   py35h7284a24_0         108 KB
#     flask-cors-3.0.3           |   py35h7e589ad_0          21 KB
#     freetype-2.8               |       h12048fb_1         541 KB
#     get_terminal_size-1.0.0    |       h7520d66_0           3 KB
#     gettext-0.19.8.1           |       h15daf44_3         2.6 MB
#     gevent-1.2.2               |   py35h8412070_0         604 KB
#     glib-2.53.6                |       h33f6a65_2         3.7 MB
#     glob2-0.6                  |   py35hdef87b6_0          17 KB
#     gmp-6.1.2                  |       hb37e062_1         505 KB
#     gmpy2-2.0.8                |   py35h212fb8a_2         144 KB
#     greenlet-0.4.12            |   py35h49b4c26_0          16 KB
#     h5py-2.7.1                 |   py35he1c7800_0         705 KB
#     hdf5-1.10.1                |       ha036c08_1         3.0 MB
#     heapdict-1.0.0             |           py35_2           8 KB
#     html5lib-1.0.1             |   py35h2f9c1c0_0         194 KB
#     icu-58.2                   |       h4b95b61_1        10.1 MB
#     idna-2.6                   |   py35h01aacb0_1         110 KB
#     imageio-2.2.0              |   py35h805106e_0         3.1 MB
#     imagesize-0.7.1            |   py35h1ad78fc_0           6 KB
#     intel-openmp-2018.0.0      |       h8158457_8         393 KB
#     ipykernel-4.8.0            |           py35_0         151 KB
#     ipython-6.2.1              |   py35h9470683_1         922 KB
#     ipython_genutils-0.2.0     |   py35hf129286_0          40 KB
#     ipywidgets-7.1.1           |           py35_0          99 KB
#     isort-4.2.15               |   py35h0db285e_0          59 KB
#     itsdangerous-0.24          |   py35hfbd69cd_1          21 KB
#     jbig-2.1                   |       h4d881f8_0          40 KB
#     jdcal-1.3                  |   py35h9028778_0          11 KB
#     jedi-0.11.1                |           py35_0         311 KB
#     jinja2-2.10                |   py35h6ff70ae_0         187 KB
#     jpeg-9b                    |       he5867d9_2         201 KB
#     jsonschema-2.6.0           |   py35h2dd9e4b_0          66 KB
#     jupyter-1.0.0              |           py35_4           6 KB
#     jupyter_client-5.2.2       |           py35_0         130 KB
#     jupyter_console-5.2.0      |   py35hd2aa692_1          36 KB
#     jupyter_core-4.4.0         |   py35h4ad9194_0          59 KB
#     jupyterlab-0.31.5          |           py35_0         4.3 MB
#     jupyterlab_launcher-0.10.2 |           py35_0          26 KB
#     lazy-object-proxy-1.3.1    |   py35h7293e74_0          28 KB
#     libcurl-7.58.0             |       hf30b1f0_0         323 KB
#     libcxx-4.0.1               |       h579ed51_0         717 KB
#     libcxxabi-4.0.1            |       hebd6815_0         118 KB
#     libedit-3.1                |       hb4e282d_0         130 KB
#     libffi-3.2.1               |       h475c297_4          37 KB
#     libgfortran-3.0.1          |       h93005f0_2         426 KB
#     libiconv-1.15              |       hdd342a3_7         671 KB
#     libpng-1.6.34              |       he12f830_0         259 KB
#     libsodium-1.0.15           |       hd9e47c5_0         212 KB
#     libssh2-1.8.0              |       h322a93b_4         204 KB
#     libtiff-4.0.9              |       h0dac147_0         387 KB
#     libxml2-2.9.7              |       hab757c2_0         1.3 MB
#     libxslt-1.1.32             |       hb819dd2_0         390 KB
#     llvmlite-0.21.0            |   py35h3a66efe_0         8.4 MB
#     locket-0.2.0               |   py35h58cf053_1           9 KB
#     lxml-4.1.1                 |   py35hef8c89e_1         1.1 MB
#     lzo-2.10                   |       h362108e_2         142 KB
#     markupsafe-1.0             |   py35h9ba0a7f_1          24 KB
#     matplotlib-2.1.2           |   py35h6d6146d_0         4.7 MB
#     mccabe-0.6.1               |   py35h3f6a9a1_0          14 KB
#     mistune-0.8.3              |           py35_0          53 KB
#     mkl-2018.0.1               |       hfbd8650_4        97.7 MB
#     mkl-service-1.1.2          |   py35h6a6947a_4           9 KB
#     mpc-1.0.3                  |       h7a72875_5          82 KB
#     mpfr-3.1.5                 |       h711e7fd_2         330 KB
#     mpmath-1.0.0               |   py35he743aed_2         801 KB
#     msgpack-python-0.5.1       |   py35h04f5b5a_0          76 KB
#     multipledispatch-0.4.9     |   py35h2fbb584_0          16 KB
#     nbconvert-5.3.1            |   py35h63fb950_0         379 KB
#     nbformat-4.4.0             |   py35h41c2038_0         127 KB
#     ncurses-6.0                |       hd04f020_2         699 KB
#     networkx-2.1               |           py35_0         1.5 MB
#     nltk-3.2.5                 |   py35h87b897b_0         1.7 MB
#     nose-1.3.7                 |   py35h9ce1e3a_2         219 KB
#     notebook-5.4.0             |           py35_0         3.7 MB
#     numba-0.36.2               |np114py35h86c4cab_0         2.1 MB
#     numexpr-2.6.4              |   py35hcf51bc4_0         111 KB
#     numpy-1.14.0               |   py35h8a80b8c_1         3.1 MB
#     numpydoc-0.7.0             |   py35h296b98c_0          39 KB
#     odo-0.5.1                  |   py35h7f7a387_0         207 KB
#     olefile-0.45.1             |           py35_0          48 KB
#     openpyxl-2.4.10            |           py35_0         306 KB
#     openssl-1.0.2n             |       hdbc3d79_0         2.3 MB
#     packaging-16.8             |   py35h2e4dc9b_0          33 KB
#     pandas-0.22.0              |   py35h0a44026_0         7.7 MB
#     pandoc-1.19.2.1            |       ha5e8f32_1        22.8 MB
#     pandocfilters-1.4.2        |   py35hff87490_1          13 KB
#     parso-0.1.1                |   py35hbda7c10_0         122 KB
#     partd-0.3.8                |   py35h6fadee7_0          33 KB
#     path.py-10.5               |   py35hcf34ba7_0          52 KB
#     pathlib2-2.3.0             |   py35hba2ddec_0          33 KB
#     patsy-0.5.0                |           py35_0         272 KB
#     pcre-8.41                  |       hfb6ab37_1         181 KB
#     pep8-1.7.1                 |           py35_0          52 KB
#     pexpect-4.3.1              |           py35_0          71 KB
#     pickleshare-0.7.4          |   py35h9517181_0          12 KB
#     pillow-5.0.0               |   py35hfcce615_0         487 KB
#     pip-9.0.1                  |   py35h33ce766_4         1.9 MB
#     pkginfo-1.4.1              |   py35h568fed1_0          41 KB
#     pluggy-0.6.0               |   py35hf57b818_0          23 KB
#     ply-3.10                   |   py35hd0aaff5_0          82 KB
#     prompt_toolkit-1.0.15      |   py35h93950c5_0         343 KB
#     psutil-5.4.3               |   py35h1de35cc_0         299 KB
#     ptyprocess-0.5.2           |   py35hfc37984_0          22 KB
#     py-1.5.2                   |   py35h4d4d87d_0         145 KB
#     pycodestyle-2.3.1          |   py35he0976b1_0          56 KB
#     pycosat-0.6.3              |   py35h745f8c1_0          81 KB
#     pycparser-2.18             |   py35hab820b0_1         169 KB
#     pycrypto-2.6.1             |   py35h1de35cc_7         357 KB
#     pycurl-7.43.0.1            |   py35hdbc3d79_0          53 KB
#     pyflakes-1.6.0             |   py35hc517269_0          89 KB
#     pygments-2.2.0             |   py35h392a662_0         1.2 MB
#     pylint-1.8.2               |           py35_0         715 KB
#     pyodbc-4.0.22              |   py35h0a44026_0          56 KB
#     pyopenssl-17.5.0           |   py35h4065cf8_0          80 KB
#     pyparsing-2.2.0            |   py35h31fab04_0          98 KB
#     pyqt-5.6.0                 |   py35hbd126f6_6         3.4 MB
#     pysocks-1.6.7              |   py35h3cfcbe1_1          23 KB
#     pytables-3.4.2             |   py35hda701c8_2         1.4 MB
#     pytest-3.3.2               |           py35_0         289 KB
#     python-3.5.4               |      he720263_23        12.2 MB
#     python-dateutil-2.6.1      |   py35h10515e0_1         226 KB
#     python.app-2               |   py35he4d1c94_7         1.1 MB
#     pytz-2017.3                |   py35heeb7564_0         177 KB
#     pywavelets-0.5.2           |   py35h9dc8fb8_0         3.0 MB
#     pyyaml-3.12                |   py35hf8cec8a_1         132 KB
#     pyzmq-16.0.3               |   py35hab9903b_0         360 KB
#     qt-5.6.2                   |      h9975529_14        52.0 MB
#     qtawesome-0.4.4            |   py35h21e61ad_0         147 KB
#     qtconsole-4.3.1            |   py35hd6d667b_0         156 KB
#     qtpy-1.3.1                 |   py35h743f03e_0          41 KB
#     readline-7.0               |       hc1231fa_4         314 KB
#     requests-2.18.4            |   py35h0d65e6b_1          97 KB
#     rope-0.10.7                |   py35h27868a4_0         298 KB
#     ruamel_yaml-0.15.35        |   py35h1de35cc_1         213 KB
#     scikit-image-0.13.1        |   py35h1de35cc_1        21.1 MB
#     scikit-learn-0.19.1        |   py35h2b554eb_0         3.6 MB
#     scipy-1.0.0                |   py35h8b35106_0        11.4 MB
#     seaborn-0.8.1              |   py35he0bbe96_0         320 KB
#     send2trash-1.4.2           |           py35_0          15 KB
#     setuptools-38.4.0          |           py35_0         477 KB
#     simplegeneric-0.8.1        |           py35_2           9 KB
#     singledispatch-3.4.0.3     |   py35h0acf360_0          16 KB
#     sip-4.18.1                 |   py35h79e1f92_2         229 KB
#     six-1.11.0                 |   py35h39a4c60_1          22 KB
#     snowballstemmer-1.2.1      |   py35hbb7be01_0          88 KB
#     sortedcollections-0.5.3    |   py35hefac527_0          15 KB
#     sortedcontainers-1.5.9     |           py35_0          46 KB
#     sphinx-1.6.6               |           py35_0         1.3 MB
#     sphinxcontrib-1.0          |   py35h3eabf46_1           4 KB
#     sphinxcontrib-websupport-1.0.1|   py35hcb4ca16_1          37 KB
#     spyder-3.2.6               |           py35_0         2.1 MB
#     sqlalchemy-1.2.1           |   py35h1de35cc_0         1.3 MB
#     sqlite-3.22.0              |       h3efe00b_0        1022 KB
#     statsmodels-0.8.0          |   py35ha7c9052_0         5.2 MB
#     sympy-1.1.1                |   py35he478fab_0         5.7 MB
#     tblib-1.3.2                |   py35h1b9c5fd_0          16 KB
#     terminado-0.8.1            |           py35_1          22 KB
#     testpath-0.3.1             |   py35hf8009f4_0          84 KB
#     tk-8.6.7                   |       h35a86e2_3         2.8 MB
#     toolz-0.9.0                |           py35_0          95 KB
#     tornado-4.5.3              |           py35_0         588 KB
#     traitlets-4.3.2            |   py35hd3d1486_0         136 KB
#     typing-3.6.2               |   py35ha402c5e_0          45 KB
#     unicodecsv-0.14.1          |   py35h2154ad0_0          26 KB
#     unixodbc-2.3.4             |       h4cb4dde_1         237 KB
#     urllib3-1.22               |   py35he002d57_0         160 KB
#     wcwidth-0.1.7              |   py35hdd0c235_0          24 KB
#     webencodings-0.5.1         |   py35hcf8ebf9_1          19 KB
#     werkzeug-0.14.1            |           py35_0         402 KB
#     wheel-0.30.0               |   py35h5c0b906_1          70 KB
#     widgetsnbextension-3.1.0   |           py35_0         636 KB
#     wrapt-1.10.11              |   py35ha18cf31_0          41 KB
#     xlrd-1.1.0                 |   py35h892fcf7_1         185 KB
#     xlsxwriter-1.0.2           |   py35h4d68a89_0         205 KB
#     xlwings-0.11.5             |           py35_0         405 KB
#     xlwt-1.2.0                 |   py35hf70d7fa_0         161 KB
#     xz-5.2.3                   |       h0278029_2         232 KB
#     yaml-0.1.7                 |       hc338f04_2          67 KB
#     zeromq-4.2.2               |       ha360ad0_2         391 KB
#     zict-0.1.3                 |   py35h1ae85d2_0          19 KB
#     zlib-1.2.11                |       hf3cbc9b_2          87 KB
#     ------------------------------------------------------------
#                                            Total:       365.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   alabaster          pkgs/main/osx-64::alabaster-0.7.10-py35hb692fe1_0 None
#   anaconda           pkgs/main/osx-64::anaconda-5.1.0-py35_2 None
#   anaconda-client    pkgs/main/osx-64::anaconda-client-1.6.9-py35_0 None
#   anaconda-project   pkgs/main/osx-64::anaconda-project-0.8.2-py35ha24014a_0 None
#   appnope            pkgs/main/osx-64::appnope-0.1.0-py35hd172556_0 None
#   appscript          pkgs/main/osx-64::appscript-1.0.1-py35hdfff33c_1 None
#   asn1crypto         pkgs/main/osx-64::asn1crypto-0.24.0-py35_0 None
#   astroid            pkgs/main/osx-64::astroid-1.6.1-py35_0 None
#   astropy            pkgs/main/osx-64::astropy-2.0.3-py35h1de35cc_0 None
#   attrs              pkgs/main/osx-64::attrs-17.4.0-py35_0 None
#   babel              pkgs/main/osx-64::babel-2.5.3-py35_0 None
#   backports          pkgs/main/osx-64::backports-1.0-py35h2556c16_1 None
#   backports.shutil_~ pkgs/main/osx-64::backports.shutil_get_terminal_size-1.0.0-py35h40fcb1f_2 None
#   beautifulsoup4     pkgs/main/osx-64::beautifulsoup4-4.6.0-py35hb75f182_1 None
#   bitarray           pkgs/main/osx-64::bitarray-0.8.1-py35h1de35cc_1 None
#   bkcharts           pkgs/main/osx-64::bkcharts-0.2-py35h18a45e2_0 None
#   blas               pkgs/main/osx-64::blas-1.0-mkl None
#   blaze              pkgs/main/osx-64::blaze-0.11.3-py35h385aa17_0 None
#   bleach             pkgs/main/osx-64::bleach-2.1.2-py35_0 None
#   bokeh              pkgs/main/osx-64::bokeh-0.12.13-py35h2f9c1c0_0 None
#   boto               pkgs/main/osx-64::boto-2.48.0-py35h10f7326_1 None
#   bottleneck         pkgs/main/osx-64::bottleneck-1.2.1-py35h969083f_0 None
#   bzip2              pkgs/main/osx-64::bzip2-1.0.6-hd86a083_4 None
#   ca-certificates    pkgs/main/osx-64::ca-certificates-2017.08.26-ha1e5d58_0 None
#   certifi            pkgs/main/osx-64::certifi-2018.1.18-py35_0 None
#   cffi               pkgs/main/osx-64::cffi-1.11.4-py35h342bebf_0 None
#   chardet            pkgs/main/osx-64::chardet-3.0.4-py35h16a84c2_1 None
#   click              pkgs/main/osx-64::click-6.7-py35hcc65ea6_0 None
#   cloudpickle        pkgs/main/osx-64::cloudpickle-0.5.2-py35_1 None
#   clyent             pkgs/main/osx-64::clyent-1.2.2-py35h63ae3d7_0 None
#   colorama           pkgs/main/osx-64::colorama-0.3.9-py35h1d66b2b_0 None
#   contextlib2        pkgs/main/osx-64::contextlib2-0.5.5-py35hc2c67b4_0 None
#   cryptography       pkgs/main/osx-64::cryptography-2.1.4-py35hbbb57dc_0 None
#   curl               pkgs/main/osx-64::curl-7.58.0-ha441bb4_0 None
#   cycler             pkgs/main/osx-64::cycler-0.10.0-py35hb89929e_0 None
#   cython             pkgs/main/osx-64::cython-0.27.3-py35h36d65b6_0 None
#   cytoolz            pkgs/main/osx-64::cytoolz-0.9.0-py35h1de35cc_0 None
#   dask               pkgs/main/osx-64::dask-0.16.1-py35_0 None
#   dask-core          pkgs/main/osx-64::dask-core-0.16.1-py35_0 None
#   datashape          pkgs/main/osx-64::datashape-0.5.4-py35hd065018_0 None
#   dbus               pkgs/main/osx-64::dbus-1.12.2-h5243cc1_1 None
#   decorator          pkgs/main/osx-64::decorator-4.2.1-py35_0 None
#   distributed        pkgs/main/osx-64::distributed-1.20.2-py35_0 None
#   docutils           pkgs/main/osx-64::docutils-0.14-py35hb13dbd9_0 None
#   entrypoints        pkgs/main/osx-64::entrypoints-0.2.3-py35h837ec6f_2 None
#   et_xmlfile         pkgs/main/osx-64::et_xmlfile-1.0.1-py35h40eb147_0 None
#   expat              pkgs/main/osx-64::expat-2.2.5-hb8e80ba_0 None
#   fastcache          pkgs/main/osx-64::fastcache-1.0.2-py35h1de35cc_2 None
#   filelock           pkgs/main/osx-64::filelock-2.0.13-py35haecd4ea_0 None
#   flask              pkgs/main/osx-64::flask-0.12.2-py35h7284a24_0 None
#   flask-cors         pkgs/main/osx-64::flask-cors-3.0.3-py35h7e589ad_0 None
#   freetype           pkgs/main/osx-64::freetype-2.8-h12048fb_1 None
#   get_terminal_size  pkgs/main/osx-64::get_terminal_size-1.0.0-h7520d66_0 None
#   gettext            pkgs/main/osx-64::gettext-0.19.8.1-h15daf44_3 None
#   gevent             pkgs/main/osx-64::gevent-1.2.2-py35h8412070_0 None
#   glib               pkgs/main/osx-64::glib-2.53.6-h33f6a65_2 None
#   glob2              pkgs/main/osx-64::glob2-0.6-py35hdef87b6_0 None
#   gmp                pkgs/main/osx-64::gmp-6.1.2-hb37e062_1 None
#   gmpy2              pkgs/main/osx-64::gmpy2-2.0.8-py35h212fb8a_2 None
#   greenlet           pkgs/main/osx-64::greenlet-0.4.12-py35h49b4c26_0 None
#   h5py               pkgs/main/osx-64::h5py-2.7.1-py35he1c7800_0 None
#   hdf5               pkgs/main/osx-64::hdf5-1.10.1-ha036c08_1 None
#   heapdict           pkgs/main/osx-64::heapdict-1.0.0-py35_2 None
#   html5lib           pkgs/main/osx-64::html5lib-1.0.1-py35h2f9c1c0_0 None
#   icu                pkgs/main/osx-64::icu-58.2-h4b95b61_1 None
#   idna               pkgs/main/osx-64::idna-2.6-py35h01aacb0_1 None
#   imageio            pkgs/main/osx-64::imageio-2.2.0-py35h805106e_0 None
#   imagesize          pkgs/main/osx-64::imagesize-0.7.1-py35h1ad78fc_0 None
#   intel-openmp       pkgs/main/osx-64::intel-openmp-2018.0.0-h8158457_8 None
#   ipykernel          pkgs/main/osx-64::ipykernel-4.8.0-py35_0 None
#   ipython            pkgs/main/osx-64::ipython-6.2.1-py35h9470683_1 None
#   ipython_genutils   pkgs/main/osx-64::ipython_genutils-0.2.0-py35hf129286_0 None
#   ipywidgets         pkgs/main/osx-64::ipywidgets-7.1.1-py35_0 None
#   isort              pkgs/main/osx-64::isort-4.2.15-py35h0db285e_0 None
#   itsdangerous       pkgs/main/osx-64::itsdangerous-0.24-py35hfbd69cd_1 None
#   jbig               pkgs/main/osx-64::jbig-2.1-h4d881f8_0 None
#   jdcal              pkgs/main/osx-64::jdcal-1.3-py35h9028778_0 None
#   jedi               pkgs/main/osx-64::jedi-0.11.1-py35_0 None
#   jinja2             pkgs/main/osx-64::jinja2-2.10-py35h6ff70ae_0 None
#   jpeg               pkgs/main/osx-64::jpeg-9b-he5867d9_2 None
#   jsonschema         pkgs/main/osx-64::jsonschema-2.6.0-py35h2dd9e4b_0 None
#   jupyter            pkgs/main/osx-64::jupyter-1.0.0-py35_4 None
#   jupyter_client     pkgs/main/osx-64::jupyter_client-5.2.2-py35_0 None
#   jupyter_console    pkgs/main/osx-64::jupyter_console-5.2.0-py35hd2aa692_1 None
#   jupyter_core       pkgs/main/osx-64::jupyter_core-4.4.0-py35h4ad9194_0 None
#   jupyterlab         pkgs/main/osx-64::jupyterlab-0.31.5-py35_0 None
#   jupyterlab_launch~ pkgs/main/osx-64::jupyterlab_launcher-0.10.2-py35_0 None
#   lazy-object-proxy  pkgs/main/osx-64::lazy-object-proxy-1.3.1-py35h7293e74_0 None
#   libcurl            pkgs/main/osx-64::libcurl-7.58.0-hf30b1f0_0 None
#   libcxx             pkgs/main/osx-64::libcxx-4.0.1-h579ed51_0 None
#   libcxxabi          pkgs/main/osx-64::libcxxabi-4.0.1-hebd6815_0 None
#   libedit            pkgs/main/osx-64::libedit-3.1-hb4e282d_0 None
#   libffi             pkgs/main/osx-64::libffi-3.2.1-h475c297_4 None
#   libgfortran        pkgs/main/osx-64::libgfortran-3.0.1-h93005f0_2 None
#   libiconv           pkgs/main/osx-64::libiconv-1.15-hdd342a3_7 None
#   libpng             pkgs/main/osx-64::libpng-1.6.34-he12f830_0 None
#   libsodium          pkgs/main/osx-64::libsodium-1.0.15-hd9e47c5_0 None
#   libssh2            pkgs/main/osx-64::libssh2-1.8.0-h322a93b_4 None
#   libtiff            pkgs/main/osx-64::libtiff-4.0.9-h0dac147_0 None
#   libxml2            pkgs/main/osx-64::libxml2-2.9.7-hab757c2_0 None
#   libxslt            pkgs/main/osx-64::libxslt-1.1.32-hb819dd2_0 None
#   llvmlite           pkgs/main/osx-64::llvmlite-0.21.0-py35h3a66efe_0 None
#   locket             pkgs/main/osx-64::locket-0.2.0-py35h58cf053_1 None
#   lxml               pkgs/main/osx-64::lxml-4.1.1-py35hef8c89e_1 None
#   lzo                pkgs/main/osx-64::lzo-2.10-h362108e_2 None
#   markupsafe         pkgs/main/osx-64::markupsafe-1.0-py35h9ba0a7f_1 None
#   matplotlib         pkgs/main/osx-64::matplotlib-2.1.2-py35h6d6146d_0 None
#   mccabe             pkgs/main/osx-64::mccabe-0.6.1-py35h3f6a9a1_0 None
#   mistune            pkgs/main/osx-64::mistune-0.8.3-py35_0 None
#   mkl                pkgs/main/osx-64::mkl-2018.0.1-hfbd8650_4 None
#   mkl-service        pkgs/main/osx-64::mkl-service-1.1.2-py35h6a6947a_4 None
#   mpc                pkgs/main/osx-64::mpc-1.0.3-h7a72875_5 None
#   mpfr               pkgs/main/osx-64::mpfr-3.1.5-h711e7fd_2 None
#   mpmath             pkgs/main/osx-64::mpmath-1.0.0-py35he743aed_2 None
#   msgpack-python     pkgs/main/osx-64::msgpack-python-0.5.1-py35h04f5b5a_0 None
#   multipledispatch   pkgs/main/osx-64::multipledispatch-0.4.9-py35h2fbb584_0 None
#   nbconvert          pkgs/main/osx-64::nbconvert-5.3.1-py35h63fb950_0 None
#   nbformat           pkgs/main/osx-64::nbformat-4.4.0-py35h41c2038_0 None
#   ncurses            pkgs/main/osx-64::ncurses-6.0-hd04f020_2 None
#   networkx           pkgs/main/osx-64::networkx-2.1-py35_0 None
#   nltk               pkgs/main/osx-64::nltk-3.2.5-py35h87b897b_0 None
#   nose               pkgs/main/osx-64::nose-1.3.7-py35h9ce1e3a_2 None
#   notebook           pkgs/main/osx-64::notebook-5.4.0-py35_0 None
#   numba              pkgs/main/osx-64::numba-0.36.2-np114py35h86c4cab_0 None
#   numexpr            pkgs/main/osx-64::numexpr-2.6.4-py35hcf51bc4_0 None
#   numpy              pkgs/main/osx-64::numpy-1.14.0-py35h8a80b8c_1 None
#   numpydoc           pkgs/main/osx-64::numpydoc-0.7.0-py35h296b98c_0 None
#   odo                pkgs/main/osx-64::odo-0.5.1-py35h7f7a387_0 None
#   olefile            pkgs/main/osx-64::olefile-0.45.1-py35_0 None
#   openpyxl           pkgs/main/osx-64::openpyxl-2.4.10-py35_0 None
#   openssl            pkgs/main/osx-64::openssl-1.0.2n-hdbc3d79_0 None
#   packaging          pkgs/main/osx-64::packaging-16.8-py35h2e4dc9b_0 None
#   pandas             pkgs/main/osx-64::pandas-0.22.0-py35h0a44026_0 None
#   pandoc             pkgs/main/osx-64::pandoc-1.19.2.1-ha5e8f32_1 None
#   pandocfilters      pkgs/main/osx-64::pandocfilters-1.4.2-py35hff87490_1 None
#   parso              pkgs/main/osx-64::parso-0.1.1-py35hbda7c10_0 None
#   partd              pkgs/main/osx-64::partd-0.3.8-py35h6fadee7_0 None
#   path.py            pkgs/main/osx-64::path.py-10.5-py35hcf34ba7_0 None
#   pathlib2           pkgs/main/osx-64::pathlib2-2.3.0-py35hba2ddec_0 None
#   patsy              pkgs/main/osx-64::patsy-0.5.0-py35_0 None
#   pcre               pkgs/main/osx-64::pcre-8.41-hfb6ab37_1 None
#   pep8               pkgs/main/osx-64::pep8-1.7.1-py35_0 None
#   pexpect            pkgs/main/osx-64::pexpect-4.3.1-py35_0 None
#   pickleshare        pkgs/main/osx-64::pickleshare-0.7.4-py35h9517181_0 None
#   pillow             pkgs/main/osx-64::pillow-5.0.0-py35hfcce615_0 None
#   pip                pkgs/main/osx-64::pip-9.0.1-py35h33ce766_4 None
#   pkginfo            pkgs/main/osx-64::pkginfo-1.4.1-py35h568fed1_0 None
#   pluggy             pkgs/main/osx-64::pluggy-0.6.0-py35hf57b818_0 None
#   ply                pkgs/main/osx-64::ply-3.10-py35hd0aaff5_0 None
#   prompt_toolkit     pkgs/main/osx-64::prompt_toolkit-1.0.15-py35h93950c5_0 None
#   psutil             pkgs/main/osx-64::psutil-5.4.3-py35h1de35cc_0 None
#   ptyprocess         pkgs/main/osx-64::ptyprocess-0.5.2-py35hfc37984_0 None
#   py                 pkgs/main/osx-64::py-1.5.2-py35h4d4d87d_0 None
#   pycodestyle        pkgs/main/osx-64::pycodestyle-2.3.1-py35he0976b1_0 None
#   pycosat            pkgs/main/osx-64::pycosat-0.6.3-py35h745f8c1_0 None
#   pycparser          pkgs/main/osx-64::pycparser-2.18-py35hab820b0_1 None
#   pycrypto           pkgs/main/osx-64::pycrypto-2.6.1-py35h1de35cc_7 None
#   pycurl             pkgs/main/osx-64::pycurl-7.43.0.1-py35hdbc3d79_0 None
#   pyflakes           pkgs/main/osx-64::pyflakes-1.6.0-py35hc517269_0 None
#   pygments           pkgs/main/osx-64::pygments-2.2.0-py35h392a662_0 None
#   pylint             pkgs/main/osx-64::pylint-1.8.2-py35_0 None
#   pyodbc             pkgs/main/osx-64::pyodbc-4.0.22-py35h0a44026_0 None
#   pyopenssl          pkgs/main/osx-64::pyopenssl-17.5.0-py35h4065cf8_0 None
#   pyparsing          pkgs/main/osx-64::pyparsing-2.2.0-py35h31fab04_0 None
#   pyqt               pkgs/main/osx-64::pyqt-5.6.0-py35hbd126f6_6 None
#   pysocks            pkgs/main/osx-64::pysocks-1.6.7-py35h3cfcbe1_1 None
#   pytables           pkgs/main/osx-64::pytables-3.4.2-py35hda701c8_2 None
#   pytest             pkgs/main/osx-64::pytest-3.3.2-py35_0 None
#   python             pkgs/main/osx-64::python-3.5.4-he720263_23 None
#   python-dateutil    pkgs/main/osx-64::python-dateutil-2.6.1-py35h10515e0_1 None
#   python.app         pkgs/main/osx-64::python.app-2-py35he4d1c94_7 None
#   pytz               pkgs/main/osx-64::pytz-2017.3-py35heeb7564_0 None
#   pywavelets         pkgs/main/osx-64::pywavelets-0.5.2-py35h9dc8fb8_0 None
#   pyyaml             pkgs/main/osx-64::pyyaml-3.12-py35hf8cec8a_1 None
#   pyzmq              pkgs/main/osx-64::pyzmq-16.0.3-py35hab9903b_0 None
#   qt                 pkgs/main/osx-64::qt-5.6.2-h9975529_14 None
#   qtawesome          pkgs/main/osx-64::qtawesome-0.4.4-py35h21e61ad_0 None
#   qtconsole          pkgs/main/osx-64::qtconsole-4.3.1-py35hd6d667b_0 None
#   qtpy               pkgs/main/osx-64::qtpy-1.3.1-py35h743f03e_0 None
#   readline           pkgs/main/osx-64::readline-7.0-hc1231fa_4 None
#   requests           pkgs/main/osx-64::requests-2.18.4-py35h0d65e6b_1 None
#   rope               pkgs/main/osx-64::rope-0.10.7-py35h27868a4_0 None
#   ruamel_yaml        pkgs/main/osx-64::ruamel_yaml-0.15.35-py35h1de35cc_1 None
#   scikit-image       pkgs/main/osx-64::scikit-image-0.13.1-py35h1de35cc_1 None
#   scikit-learn       pkgs/main/osx-64::scikit-learn-0.19.1-py35h2b554eb_0 None
#   scipy              pkgs/main/osx-64::scipy-1.0.0-py35h8b35106_0 None
#   seaborn            pkgs/main/osx-64::seaborn-0.8.1-py35he0bbe96_0 None
#   send2trash         pkgs/main/osx-64::send2trash-1.4.2-py35_0 None
#   setuptools         pkgs/main/osx-64::setuptools-38.4.0-py35_0 None
#   simplegeneric      pkgs/main/osx-64::simplegeneric-0.8.1-py35_2 None
#   singledispatch     pkgs/main/osx-64::singledispatch-3.4.0.3-py35h0acf360_0 None
#   sip                pkgs/main/osx-64::sip-4.18.1-py35h79e1f92_2 None
#   six                pkgs/main/osx-64::six-1.11.0-py35h39a4c60_1 None
#   snowballstemmer    pkgs/main/osx-64::snowballstemmer-1.2.1-py35hbb7be01_0 None
#   sortedcollections  pkgs/main/osx-64::sortedcollections-0.5.3-py35hefac527_0 None
#   sortedcontainers   pkgs/main/osx-64::sortedcontainers-1.5.9-py35_0 None
#   sphinx             pkgs/main/osx-64::sphinx-1.6.6-py35_0 None
#   sphinxcontrib      pkgs/main/osx-64::sphinxcontrib-1.0-py35h3eabf46_1 None
#   sphinxcontrib-web~ pkgs/main/osx-64::sphinxcontrib-websupport-1.0.1-py35hcb4ca16_1 None
#   spyder             pkgs/main/osx-64::spyder-3.2.6-py35_0 None
#   sqlalchemy         pkgs/main/osx-64::sqlalchemy-1.2.1-py35h1de35cc_0 None
#   sqlite             pkgs/main/osx-64::sqlite-3.22.0-h3efe00b_0 None
#   statsmodels        pkgs/main/osx-64::statsmodels-0.8.0-py35ha7c9052_0 None
#   sympy              pkgs/main/osx-64::sympy-1.1.1-py35he478fab_0 None
#   tblib              pkgs/main/osx-64::tblib-1.3.2-py35h1b9c5fd_0 None
#   terminado          pkgs/main/osx-64::terminado-0.8.1-py35_1 None
#   testpath           pkgs/main/osx-64::testpath-0.3.1-py35hf8009f4_0 None
#   tk                 pkgs/main/osx-64::tk-8.6.7-h35a86e2_3 None
#   toolz              pkgs/main/osx-64::toolz-0.9.0-py35_0 None
#   tornado            pkgs/main/osx-64::tornado-4.5.3-py35_0 None
#   traitlets          pkgs/main/osx-64::traitlets-4.3.2-py35hd3d1486_0 None
#   typing             pkgs/main/osx-64::typing-3.6.2-py35ha402c5e_0 None
#   unicodecsv         pkgs/main/osx-64::unicodecsv-0.14.1-py35h2154ad0_0 None
#   unixodbc           pkgs/main/osx-64::unixodbc-2.3.4-h4cb4dde_1 None
#   urllib3            pkgs/main/osx-64::urllib3-1.22-py35he002d57_0 None
#   wcwidth            pkgs/main/osx-64::wcwidth-0.1.7-py35hdd0c235_0 None
#   webencodings       pkgs/main/osx-64::webencodings-0.5.1-py35hcf8ebf9_1 None
#   werkzeug           pkgs/main/osx-64::werkzeug-0.14.1-py35_0 None
#   wheel              pkgs/main/osx-64::wheel-0.30.0-py35h5c0b906_1 None
#   widgetsnbextension pkgs/main/osx-64::widgetsnbextension-3.1.0-py35_0 None
#   wrapt              pkgs/main/osx-64::wrapt-1.10.11-py35ha18cf31_0 None
#   xlrd               pkgs/main/osx-64::xlrd-1.1.0-py35h892fcf7_1 None
#   xlsxwriter         pkgs/main/osx-64::xlsxwriter-1.0.2-py35h4d68a89_0 None
#   xlwings            pkgs/main/osx-64::xlwings-0.11.5-py35_0 None
#   xlwt               pkgs/main/osx-64::xlwt-1.2.0-py35hf70d7fa_0 None
#   xz                 pkgs/main/osx-64::xz-5.2.3-h0278029_2 None
#   yaml               pkgs/main/osx-64::yaml-0.1.7-hc338f04_2 None
#   zeromq             pkgs/main/osx-64::zeromq-4.2.2-ha360ad0_2 None
#   zict               pkgs/main/osx-64::zict-0.1.3-py35h1ae85d2_0 None
#   zlib               pkgs/main/osx-64::zlib-1.2.11-hf3cbc9b_2 None
#
#
# Proceed ([y]/n)?

# %%
y

# %%
activate newenvt

# %%
import pandas as pd
from process_text import process_text
import utilities

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from keras.utils.np_utils import to_categorical
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
if __name__ == "__main__":
    # load the required NLTK data and resources
    utilities.download("punkt")
    utilities.download('universal_tagset')

    # read the requirements.csv file into a dataframe
    df = pd.read_csv('./assets/csv/requirements.csv')
    
    # get the sentences and labels from the dataframe
    sentences = df['text'].tolist()
    labels = df['label'].tolist()

    # use the list of sentences to call the process_text function 
    # and write the result to a csv file
    df_results = pd.DataFrame(columns=['label', 'sentence', 'syntax'])
    for i, sentence in enumerate(sentences):
        print(i)
        entities = process_text(sentence)
        syntax = ''
        for entity in entities:
            syntax = syntax + entity[0] + ' '
        df_temp = pd.DataFrame({'label': [labels[i]], 'sentence': [sentence], 'syntax': [syntax]})
        df_results = pd.concat([df_results, df_temp], ignore_index=True)
    df_results.to_csv('./assets/csv/results.csv', index=False)

# Read the CSV file into a dataframe
df = pd.read_csv('./assets/csv/results.csv')

# Split the data into training and testing sets
train_df, test_df = train_test_split(df, test_size=0.2)

# Encode the labels as integers
label_encoder = LabelEncoder()
train_df['label'] = label_encoder.fit_transform(train_df['label'])
test_df['label'] = label_encoder.transform(test_df['label'])

# Tokenize the text
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(train_df['syntax'])
train_sequences = tokenizer.texts_to_sequences(train_df['syntax'])
test_sequences = tokenizer.texts_to_sequences(test_df['syntax'])

# Pad the sequences to the same length
max_length = max([len(s) for s in train_sequences + test_sequences])
train_data = pad_sequences(train_sequences, maxlen=max_length)
test_data = pad_sequences(test_sequences, maxlen=max_length)

# Convert the labels to one-hot encoded arrays
train_labels = to_categorical(train_df['label'], num_classes=len(label_encoder.classes_))
test_labels = to_categorical(test_df['label'], num_classes=len(label_encoder.classes_))

# Define the neural network architecture
model = Sequential()
model.add(Embedding(5000, 100, input_length=max_length))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(256, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(len(label_encoder.classes_), activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['binary_accuracy'])

# Train the model
model.fit(train_data, train_labels, epochs=250, batch_size=535, validation_data=(test_data, test_labels))

# Make predictions on the test set and calculate metrics
y_true = np.argmax(test_labels, axis=1)
y_pred = np.argmax(model.predict(test_data), axis=1)

# Calculate metrics
acc = accuracy_score(y_test, y_pred)
precision, recall, f1_score, support = precision_recall_fscore_support(y_test, y_pred, average=None)

# %%
print("Accuracy: ", acc)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1_score)
print("Support: ", support)

# Print classification report
print(classification_report(y_test, y_pred))
