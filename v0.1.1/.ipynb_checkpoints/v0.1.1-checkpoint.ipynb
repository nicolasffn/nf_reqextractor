# %%
import pandas as pnd

dfRequirements = pnd.read_csv ('assets/csv/requirements.csv') 
dfRequirements.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535 entries, 0 to 534
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   535 non-null    object
#  1   text    535 non-null    object
# dtypes: object(2)
# memory usage: 8.5+ KB

# %%
dfRequirementsBis = pnd.read_csv ('assets/csv/requirements_bis.csv') 
dfRequirementsBis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188 entries, 0 to 1187
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   1188 non-null   object
#  1   text    1188 non-null   object
# dtypes: object(2)
# memory usage: 18.7+ KB

# %%
dfRequirements.columns = ['label', 'text']
dfRequirementsBis.columns = ['label', 'text']

# %%
dfRequirements.describe()
# Out:
#        label                                               text
# count    535                                                535
# unique     8                                                532
# top        F  Only registered customers can purchase streami...
# freq     255                                                  2

# %%
print(dfRequirements['label'].value_counts())
print(dfRequirementsBis['label'].value_counts())
# Out:
# F     254
# US     67
# SE     66
# PE     53
# LF     38
# A      21
# SC     21
# L      13
# Name: label, dtype: int64
# F     303
# US    164
# PE    142
# SE    135
# LF    123
# A      90
# SC     89
# L      33
# Name: label, dtype: int64

# %%
dfRequirements = dfRequirements.drop_duplicates()
dfRequirements.describe()
# Out:
#        label                                               text
# count    533                                                533
# unique     8                                                532
# top        F  Only registered customers can purchase streami...
# freq     254                                                  2

# %%
dfRequirementsBis = dfRequirementsBis.drop_duplicates()
dfRequirementsBis.describe()
# Out:
#        label                                               text
# count   1079                                               1079
# unique     8                                               1076
# top        F  Only registered customers can purchase streami...
# freq     303                                                  2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Tracer les graphiques
ax = dfRequirements.groupby(by='label').size().plot(kind='bar', alpha=0.5, color='b')
dfRequirementsBis.groupby(by='label').size().plot(kind='bar', alpha=0.5, color='g')

# Ajouter les étiquettes d'axe et le titre
plt.title('Number of Requirements by Label')
plt.xlabel('Label')
plt.ylabel('Requirements')

# Ajouter la légende
plt.legend(['dfRequirements', 'dfRequirementsBis'])

# Afficher le graphique
plt.show()

# %%
print(dfRequirements['label'].value_counts())
print(dfRequirementsBis['label'].value_counts())
# Out:
# F     254
# US     67
# SE     66
# PE     53
# LF     38
# A      21
# SC     21
# L      13
# Name: label, dtype: int64
# F     303
# US    164
# PE    142
# SE    135
# LF    123
# A      90
# SC     89
# L      33
# Name: label, dtype: int64

# %%
dfEpoches = pnd.read_csv ('assets/csv/epoches.csv') 
dfEpoches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   epcoh                276 non-null    object
#  1   loss                 275 non-null    float64
#  2   binary_accuracy      275 non-null    float64
#  3   val_loss             275 non-null    float64
#  4   val_binary_accuracy  275 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 10.9+ KB

# %%
dfEpoches.columns = ['epcoh', 'loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Tracer le graphique pour la perte et l'exactitude binaire à chaque époque
fig, ax = plt.subplots(2, 1, figsize=(10, 10))
ax[0].plot(dfEpoches["epcoh"], dfEpoches["loss"], label="Training Loss")
ax[0].plot(dfEpoches["epcoh"], dfEpoches["val_loss"], label="Validation Loss")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss")
ax[0].legend()

ax[1].plot(dfEpoches["epcoh"], dfEpoches["binary_accuracy"], label="Training Accuracy")
ax[1].plot(dfEpoches["epcoh"], dfEpoches["val_binary_accuracy"], label="Validation Accuracy")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Accuracy")
ax[1].legend()

plt.show()
